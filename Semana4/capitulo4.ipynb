# %% [markdown]
# # Funciones
# ## Definición
# Una función es una **secuencia de sentencias que realizan una operación y que reciben un nombre.**

# %%
type(32)
# Out:
# int

# %% [markdown]
# - El nombre de la función es type. La expresión **entre paréntesis recibe el nombre de argumento de la función.**
# - El argumento es un valor o variable que se **pasa a la función como parámetro de entrada.**
# - El resultado de la función type es el tipo del argumento.
# - Es habitual decir que una función “toma” (o recibe) un argumento y “retorna” (o devuelve) un resultado.
# **El resultado se llama valor de retorno.**
# Argumento Esta en la definicion de la funcion.
# El parametros es el valor real que le pasamos a la función.
#
# ![image.png](attachment:image.png)

# %%
max("Hello World")
#print(max("Hello World!"))
max(1, 3)
type(max(1, 2))
# Out:
# int

# %%
print("Hola")
def mi_funcion():
    print("Ya estamos dentro de la funcion")
    print("Esto tambien es funcion")

x = 5
x += 5
print(x)
mi_funcion()
print("final del codigo")
# Out:
# Hola
# 10
# Ya estamos dentro de la funcion
# Esto tambien es funcion
# final del codigo

# %%
def idioma(lang):
    if lang == 'es':
        print("1. Castellano")
    elif lang == 'val':
        print("2. Valenciano")
    else:
        print("No sabemos q idioma es.")

print("Que idioma hablas")
idioma('es')
print("Pues yo hablo ")
idioma('val')
print("\tSi pongo dentro si intento hacer esto rr = idioma('val') devuelve None\n"
"\t- ESTA FUUNCION NO DEVUELVE NADA = None\n \t- Luego Nome es lo que se mete en la variable \n\t- Si definimos la variable con parametros y no se los damos da error.")
#idioma()
# Out:
# Que idioma hablas
# 1. Castellano
# Pues yo hablo
# 2. Valenciano
# 	Si pongo dentro si intento hacer esto rr = idioma('val') devuelve None
# 	- ESTA FUUNCION NO DEVUELVE NADA = None
#  	- Luego Nome es lo que se mete en la variable
# 	- Si definimos la variable con parametros y no se los damos da error.

# %%
def grito():
    return -1.0
#print(grito())
grito()
type(grito())
# Out:
# float
